# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

from tensorflow.keras import mixed_precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)

train_dir = '/content/drive/MyDrive/LungCancer/Data/train'
valid_dir = '/content/drive/MyDrive/LungCancer/Data/valid'
test_dir = '/content/drive/MyDrive/LungCancer/Data/test'



image_shape = (224, 224, 3)
N_CLASSES = 4
BATCH_SIZE = 16
train_datagen = ImageDataGenerator(dtype='float32', rescale=1.0 / 255.0)
valid_datagen = ImageDataGenerator(dtype='float32', rescale=1.0 / 255.0)
test_datagen = ImageDataGenerator(dtype='float32', rescale=1.0 / 255.0)

train_generator = train_datagen.flow_from_directory(
    train_dir, batch_size=BATCH_SIZE, target_size=image_shape[:2], class_mode='categorical'
)
valid_generator = valid_datagen.flow_from_directory(
    valid_dir, batch_size=BATCH_SIZE, target_size=image_shape[:2], class_mode='categorical'
)
test_generator = test_datagen.flow_from_directory(
    test_dir, batch_size=BATCH_SIZE, target_size=image_shape[:2], class_mode='categorical'
)

vgg_model = VGG16(include_top=False, pooling='avg', weights='imagenet', input_shape=image_shape)
for layer in vgg_model.layers:
    layer.trainable = False

model = Sequential([
    vgg_model,
    Flatten(),
    BatchNormalization(),
    Dense(512, activation='relu'),
    Dense(N_CLASSES, activation='softmax')
])
model.summary()

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

checkpointer = ModelCheckpoint(
    filepath='./vgg16_model.keras',
    monitor='val_loss',
    verbose=1,
    save_best_only=True
)
early_stopping = EarlyStopping(verbose=1, patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

# Learning Rate Scheduler function
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    elif epoch < 20:
        return lr * 0.9  # Gradually reduce by 10%
    else:
        return lr * 0.8  # Gradual reduction

lr_scheduler = LearningRateScheduler(scheduler)

history_vgg = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=100,
    validation_data=valid_generator,
    callbacks=[checkpointer, early_stopping, reduce_lr, lr_scheduler],
    verbose=1
)


for layer in vgg_model.layers[-4:]:  # Unfreeze last few layers
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

history_finetune = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=valid_generator,
    callbacks=[checkpointer, early_stopping, reduce_lr],
    verbose=1
)

def plot_training(history):
    plt.figure(figsize=(12, 4))
    # Accuracy Plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.show()

plot_training(history_vgg)
plot_training(history_finetune)
# Out:
# Found 622 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 512)            │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,981,444 (57.15 MB)
#  Trainable params: 265,732 (1.01 MB)
#  Non-trainable params: 14,715,712 (56.14 MB)
# Epoch 1/100
# 38/39 ━━━━━━━━━━━━━━━━━━━━ 3s 4s/step - accuracy: 0.5822 - loss: 0.9988
# Epoch 1: val_loss improved from None to 1.22059, saving model to ./vgg16_model.keras
#
# Epoch 1: finished saving model to ./vgg16_model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 181s 4s/step - accuracy: 0.6736 - loss: 0.8216 - val_accuracy: 0.3333 - val_loss: 1.2206 - learning_rate: 0.0010
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9090 - loss: 0.3107
# Epoch 2: val_loss did not improve from 1.22059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9196 - loss: 0.2770 - val_accuracy: 0.2083 - val_loss: 1.3947 - learning_rate: 0.0010
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9755 - loss: 0.1336
# Epoch 3: val_loss did not improve from 1.22059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.9727 - loss: 0.1243 - val_accuracy: 0.2361 - val_loss: 1.2636 - learning_rate: 0.0010
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9845 - loss: 0.0845
# Epoch 4: val_loss improved from 1.22059 to 1.20260, saving model to ./vgg16_model.keras
#
# Epoch 4: finished saving model to ./vgg16_model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 0.9839 - loss: 0.0877 - val_accuracy: 0.3056 - val_loss: 1.2026 - learning_rate: 0.0010
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9960 - loss: 0.0470
# Epoch 5: val_loss improved from 1.20260 to 1.09385, saving model to ./vgg16_model.keras
#
# Epoch 5: finished saving model to ./vgg16_model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 173ms/step - accuracy: 0.9920 - loss: 0.0536 - val_accuracy: 0.5139 - val_loss: 1.0939 - learning_rate: 0.0010
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9975 - loss: 0.0423
# Epoch 6: val_loss improved from 1.09385 to 0.93792, saving model to ./vgg16_model.keras
#
# Epoch 6: finished saving model to ./vgg16_model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - accuracy: 0.9968 - loss: 0.0408 - val_accuracy: 0.6250 - val_loss: 0.9379 - learning_rate: 9.0000e-04
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9992 - loss: 0.0257
# Epoch 7: val_loss improved from 0.93792 to 0.81922, saving model to ./vgg16_model.keras
#
# Epoch 7: finished saving model to ./vgg16_model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - accuracy: 0.9984 - loss: 0.0246 - val_accuracy: 0.7222 - val_loss: 0.8192 - learning_rate: 8.1000e-04
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9993 - loss: 0.0214
# Epoch 8: val_loss improved from 0.81922 to 0.74749, saving model to ./vgg16_model.keras
#
# Epoch 8: finished saving model to ./vgg16_model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 0.9984 - loss: 0.0251 - val_accuracy: 0.7500 - val_loss: 0.7475 - learning_rate: 7.2900e-04
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9995 - loss: 0.0158
# Epoch 9: val_loss improved from 0.74749 to 0.59330, saving model to ./vgg16_model.keras
#
# Epoch 9: finished saving model to ./vgg16_model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - accuracy: 0.9984 - loss: 0.0166 - val_accuracy: 0.8472 - val_loss: 0.5933 - learning_rate: 6.5610e-04
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9988 - loss: 0.0171
# Epoch 10: val_loss improved from 0.59330 to 0.56572, saving model to ./vgg16_model.keras
#
# Epoch 10: finished saving model to ./vgg16_model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9984 - loss: 0.0212 - val_accuracy: 0.8333 - val_loss: 0.5657 - learning_rate: 5.9049e-04
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9991 - loss: 0.0144
# Epoch 11: val_loss did not improve from 0.56572
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9968 - loss: 0.0193 - val_accuracy: 0.8194 - val_loss: 0.6082 - learning_rate: 5.3144e-04
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9953 - loss: 0.0183
# Epoch 12: val_loss did not improve from 0.56572
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9968 - loss: 0.0180 - val_accuracy: 0.8611 - val_loss: 0.5658 - learning_rate: 4.7830e-04
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9990 - loss: 0.0142
# Epoch 13: val_loss improved from 0.56572 to 0.56206, saving model to ./vgg16_model.keras
#
# Epoch 13: finished saving model to ./vgg16_model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 174ms/step - accuracy: 0.9984 - loss: 0.0120 - val_accuracy: 0.8750 - val_loss: 0.5621 - learning_rate: 4.3047e-04
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9986 - loss: 0.0104
# Epoch 14: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9984 - loss: 0.0126 - val_accuracy: 0.8750 - val_loss: 0.5666 - learning_rate: 3.8742e-04
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9985 - loss: 0.0108
# Epoch 15: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 165ms/step - accuracy: 0.9968 - loss: 0.0132 - val_accuracy: 0.8750 - val_loss: 0.5794 - learning_rate: 3.4868e-04
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9988 - loss: 0.0070
# Epoch 16: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9984 - loss: 0.0101 - val_accuracy: 0.8750 - val_loss: 0.6078 - learning_rate: 3.1381e-04
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9973 - loss: 0.0094
# Epoch 17: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - accuracy: 0.9968 - loss: 0.0118 - val_accuracy: 0.8750 - val_loss: 0.6274 - learning_rate: 2.8243e-04
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9993 - loss: 0.0067
# Epoch 18: val_loss did not improve from 0.56206
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00012709329894278198.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9984 - loss: 0.0081 - val_accuracy: 0.8611 - val_loss: 0.6334 - learning_rate: 1.2709e-04
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9986 - loss: 0.0060
# Epoch 19: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9968 - loss: 0.0083 - val_accuracy: 0.8611 - val_loss: 0.6372 - learning_rate: 1.1438e-04
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9997 - loss: 0.0062
# Epoch 20: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - accuracy: 0.9984 - loss: 0.0079 - val_accuracy: 0.8611 - val_loss: 0.6588 - learning_rate: 1.0295e-04
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9973 - loss: 0.0115
# Epoch 21: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 11s 168ms/step - accuracy: 0.9984 - loss: 0.0096 - val_accuracy: 0.8750 - val_loss: 0.6480 - learning_rate: 8.2356e-05
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9994 - loss: 0.0066
# Epoch 22: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9984 - loss: 0.0074 - val_accuracy: 0.8750 - val_loss: 0.6579 - learning_rate: 6.5885e-05
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9965 - loss: 0.0092
# Epoch 23: val_loss did not improve from 0.56206
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.635406781337224e-05.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9968 - loss: 0.0097 - val_accuracy: 0.8611 - val_loss: 0.6680 - learning_rate: 2.6354e-05
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 24: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8611 - val_loss: 0.6701 - learning_rate: 2.1083e-05
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9979 - loss: 0.0070
# Epoch 25: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.9984 - loss: 0.0065 - val_accuracy: 0.8611 - val_loss: 0.6712 - learning_rate: 1.6867e-05
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9976 - loss: 0.0095
# Epoch 26: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 165ms/step - accuracy: 0.9968 - loss: 0.0102 - val_accuracy: 0.8611 - val_loss: 0.6726 - learning_rate: 1.3493e-05
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 27: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.8611 - val_loss: 0.6724 - learning_rate: 1.0795e-05
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 28: val_loss did not improve from 0.56206
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.317850653023925e-06.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.9984 - loss: 0.0072 - val_accuracy: 0.8611 - val_loss: 0.6736 - learning_rate: 4.3179e-06
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Epoch 1/50
# 38/39 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 1: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 323ms/step - accuracy: 0.9984 - loss: 0.0128 - val_accuracy: 0.8194 - val_loss: 0.8394 - learning_rate: 1.0000e-05
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9991 - loss: 0.0052
# Epoch 2: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9968 - loss: 0.0098 - val_accuracy: 0.8889 - val_loss: 0.6286 - learning_rate: 1.0000e-05
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9987 - loss: 0.0074
# Epoch 3: val_loss did not improve from 0.56206
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 10s 143ms/step - accuracy: 0.9968 - loss: 0.0136 - val_accuracy: 0.8611 - val_loss: 0.6265 - learning_rate: 1.0000e-05
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9992 - loss: 0.0071
# Epoch 4: val_loss improved from 0.56206 to 0.51320, saving model to ./vgg16_model.keras
#
# Epoch 4: finished saving model to ./vgg16_model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - accuracy: 0.9984 - loss: 0.0100 - val_accuracy: 0.8889 - val_loss: 0.5132 - learning_rate: 1.0000e-05
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9977 - loss: 0.0128
# Epoch 5: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 0.9984 - loss: 0.0095 - val_accuracy: 0.8889 - val_loss: 0.5648 - learning_rate: 1.0000e-05
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9998 - loss: 0.0025
# Epoch 6: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 0.9984 - loss: 0.0079 - val_accuracy: 0.8750 - val_loss: 0.7467 - learning_rate: 1.0000e-05
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9997 - loss: 0.0025
# Epoch 7: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9984 - loss: 0.0076 - val_accuracy: 0.8750 - val_loss: 0.7232 - learning_rate: 1.0000e-05
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9973 - loss: 0.0050
# Epoch 8: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - accuracy: 0.9984 - loss: 0.0034 - val_accuracy: 0.9028 - val_loss: 0.6560 - learning_rate: 1.0000e-05
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9988 - loss: 0.0029
# Epoch 9: val_loss did not improve from 0.51320
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 0.9984 - loss: 0.0034 - val_accuracy: 0.9028 - val_loss: 0.6747 - learning_rate: 1.0000e-05
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9986 - loss: 0.0031
# Epoch 10: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9968 - loss: 0.0061 - val_accuracy: 0.9028 - val_loss: 0.6361 - learning_rate: 5.0000e-06
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9967 - loss: 0.0038
# Epoch 11: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - accuracy: 0.9968 - loss: 0.0035 - val_accuracy: 0.9028 - val_loss: 0.7252 - learning_rate: 5.0000e-06
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9996 - loss: 0.0014
# Epoch 12: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.9984 - loss: 0.0032 - val_accuracy: 0.9028 - val_loss: 0.6544 - learning_rate: 5.0000e-06
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 8.7200e-04
# Epoch 13: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9984 - loss: 0.0042 - val_accuracy: 0.9028 - val_loss: 0.6369 - learning_rate: 5.0000e-06
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9991 - loss: 0.0019
# Epoch 14: val_loss did not improve from 0.51320
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9968 - loss: 0.0083 - val_accuracy: 0.8889 - val_loss: 0.7654 - learning_rate: 5.0000e-06
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9989 - loss: 0.0068
# Epoch 15: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - accuracy: 0.9984 - loss: 0.0037 - val_accuracy: 0.8889 - val_loss: 0.7526 - learning_rate: 2.5000e-06
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9984 - loss: 0.0023
# Epoch 16: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.9968 - loss: 0.0046 - val_accuracy: 0.9028 - val_loss: 0.7310 - learning_rate: 2.5000e-06
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9994 - loss: 0.0014
# Epoch 17: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9984 - loss: 0.0031 - val_accuracy: 0.9028 - val_loss: 0.7038 - learning_rate: 2.5000e-06
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9980 - loss: 0.0034
# Epoch 18: val_loss did not improve from 0.51320
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.9984 - loss: 0.0035 - val_accuracy: 0.9028 - val_loss: 0.6827 - learning_rate: 2.5000e-06
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9900 - loss: 0.0113
# Epoch 19: val_loss did not improve from 0.51320
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - accuracy: 0.9968 - loss: 0.0046 - val_accuracy: 0.9028 - val_loss: 0.6901 - learning_rate: 2.5000e-06
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %%
import os

# Desired directory to save the model
save_dir = '/content/drive/MyDrive/lungcancer/saved_models'

# Create the directory if it does not exist
os.makedirs(save_dir, exist_ok=True)

# Save the model in Keras format
keras_model_path = os.path.join(save_dir, 'vgg16_model.keras')
model.save(keras_model_path)
print(f"Model saved in Keras format at: {keras_model_path}")

# Save the model in HDF5 format
h5_model_path = os.path.join(save_dir, 'vgg16_model.h5')
model.save(h5_model_path)
print(f"Model saved in HDF5 format at: {h5_model_path}")

# Save the model in TensorFlow SavedModel format using `export`
saved_model_dir = os.path.join(save_dir, 'saved_model/vgg16_model')
model.export(saved_model_dir)  # Use `export()` for SavedModel format
print(f"Model exported in TensorFlow SavedModel format at: {saved_model_dir}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved in Keras format at: /content/drive/MyDrive/lungcancer/saved_models/vgg16_model.keras
# Model saved in HDF5 format at: /content/drive/MyDrive/lungcancer/saved_models/vgg16_model.h5
# Saved artifact at '/content/drive/MyDrive/lungcancer/saved_models/saved_model/vgg16_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float16, name='keras_tensor_322')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float16, name=None)
# Captures:
#   135466902460496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466902713472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466902713648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135467937948496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466902114320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466899539040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466899552944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466899554000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466899548720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466899544496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466899542032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897739088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897740672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897736800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897748768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897743312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897751584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897747184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897751760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897741376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897744896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466896923232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466896926048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466896922176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466896928864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466896924992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897054128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897052016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897052720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897054656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897054832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897056944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897056416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135466897058000: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model exported in TensorFlow SavedModel format at: /content/drive/MyDrive/lungcancer/saved_models/saved_model/vgg16_model

# %%
from tensorflow.keras.models import load_model

# Load the model saved in .keras format
loaded_model_keras = load_model('vgg16_model.keras')
test_loss, test_accuracy = loaded_model_keras.evaluate(test_generator)
print(f"\nTest Accuracy (Keras format): {test_accuracy * 100:.2f}%")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 268ms/step - accuracy: 0.8763 - loss: 0.4607
#
# Test Accuracy (Keras format): 89.21%

# %%
import os

# Desired directory to save the model
save_dir = '/content/drive/MyDrive/lungcancer/saved_models'

# Create the directory if it does not exist
os.makedirs(save_dir, exist_ok=True)

# Save the model in Keras format (recommended)
keras_model_path = os.path.join(save_dir, 'vgg16_model.keras')
model.save(keras_model_path)
print(f"Model saved in Keras format at: {keras_model_path}")

# Save the model in TensorFlow SavedModel format
saved_model_dir = os.path.join(save_dir, 'saved_model/vgg16_model')
model.export(saved_model_dir)  # Use `export()` for SavedModel format
print(f"Model exported in TensorFlow SavedModel format at: {saved_model_dir}")
# Out:
# Model saved in Keras format at: /content/drive/MyDrive/lungcancer/saved_models/vgg16_model.keras
# Saved artifact at '/content/drive/MyDrive/lungcancer/saved_models/saved_model/vgg16_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float16, name='keras_tensor_21')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float16, name=None)
# Captures:
#   135114242707472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242706512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242708816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242707664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242707856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242709392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242709968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242710736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242711312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242711888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242709584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242712656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242713808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242713040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242714768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242714000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242714576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242712848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242710160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242715344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242716688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242714960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242717072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242716880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242717456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242717264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242719184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242708048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242718800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242710352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242718224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242719376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242718992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135114242718608: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model exported in TensorFlow SavedModel format at: /content/drive/MyDrive/lungcancer/saved_models/saved_model/vgg16_model

# %%
from tensorflow.keras.models import load_model
import os

# Define the path to the saved Keras model
save_dir = '/content/drive/MyDrive/lungcancer/saved_models'
kera_model_path = os.path.join(save_dir, 'vgg16_model.keras')

# Load the model saved in .keras format
loaded_model_keras = load_model(kera_model_path)

# Evaluate the loaded model on the test generator
test_loss, test_accuracy = loaded_model_keras.evaluate(test_generator)
print(f"\nTest Accuracy (loaded Keras model): {test_accuracy * 100:.2f}%")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 109s 5s/step - accuracy: 0.8762 - loss: 0.3549
#
# Test Accuracy (loaded Keras model): 87.62%

# %%
import numpy as np
import matplotlib.pyplot as plt

# Get a batch of test images and labels
images, true_labels = next(test_generator)

# Get class names from the generator
class_names = list(test_generator.class_indices.keys())

# Make predictions on the batch
predictions = loaded_model_keras.predict(images)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(true_labels, axis=1)

# Plot the images with predictions
plt.figure(figsize=(15, 10))
for i in range(min(len(images), 12)): # Display up to 9 images
    plt.subplot(3, 4, i + 1)
    plt.imshow(images[i])
    plt.axis('off')

    true_label_name = class_names[true_classes[i]]
    predicted_label_name = class_names[predicted_classes[i]]

    color = "green" if predicted_classes[i] == true_classes[i] else "red"
    plt.title(f"True: {true_label_name}\nPred: {predicted_label_name}", color=color)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %%
from sklearn.metrics import classification_report
import numpy as np

# Reset the test generator to ensure all images are processed from the start
test_generator.reset()

# Get all true labels from the test generator
y_true = []
for i in range(len(test_generator)):
    _, labels_batch = next(test_generator) # Corrected: use next() and unpack
    y_true.extend(np.argmax(labels_batch, axis=1))

# Get all predictions from the model for the test generator
test_generator.reset()
y_pred_raw = loaded_model_keras.predict(test_generator)
y_pred = np.argmax(y_pred_raw, axis=1)

# Get class names from the generator
class_names = list(test_generator.class_indices.keys())

# Generate and print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step
#                          precision    recall  f1-score   support
#
#          adenocarcinoma       0.93      0.79      0.86       120
#    large.cell.carcinoma       0.77      0.92      0.84        51
#                  normal       0.98      0.98      0.98        54
# squamous.cell.carcinoma       0.83      0.90      0.86        90
#
#                accuracy                           0.88       315
#               macro avg       0.88      0.90      0.88       315
#            weighted avg       0.88      0.88      0.88       315

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Calculate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Display the confusion matrix
fig, ax = plt.subplots(figsize=(10, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, ax=ax)
plt.title('Confusion Matrix')
plt.show()
